# %%
import pandas as pd
import numpy as np
 
data = {
    'Prestaciones Económicas':
      [
        'P01 Solicitud de Pago inicial',
        'P02 Correccion origen y/o datos de la  incapacidad',
        'P03 Solicitud de informacion tramites pago y transcripcion',
        'P04 Solicitud de incapacidad y/o licencia con pago ya autorizado',
        'P05 Solicitud de incapacidad en proceso de autorizacion menor a 15 días',
        'P06 Solicitud de pago a tercero autorizado por  fallecimiento del cotizante',
        'P07 Solicitud de retoma de Incapacidad y/o licencia por negacion anterior',
        'P08 Solicitud de Reliquidacion y/o ajuste en el valor liquidado',
        'P09 Mala atencion de OAA no radican solicitud de pago',
        'P10 Solicitud de pago de Incapacidad Inferior a 3 Días',
        'P11 Solicitud de pago de incapacidades mayores a 180 días',
        'P12 Solicitud de pago de incapacidades mayores a 540 días',
        'P13 Solicitud de aclaracion de pago de incapacidades',
        'P14 Solicitud de certificado detallado de incapacidades',
        'P15 Usuario asignacion (Incapacidad Generada en EPS anterior)',
        'P16 Solicitud pago de incapacidad AT o EP',
        'P17 Incapacidad perdio vigencia para cobro',
        'P18 Solicitud de aclaracion de negacion de pago',
        'P19 Solicitud de pago de incapacidades reconocidas por tracto sucesivo-tutela',
        'P20 solicitud de reconocimiento por cumpliento de fallos de tutela',
        'P21 Solicitud de Aportante masivo',
        'P22 Información solicitud no es queja'
      ]
      } 
P01 = {
    'P01_Solicitud_de_Pago_inicial':
      [
        'P01_1 Solicitud de Pago inicial que no se logrado realizar por Portal', 
        'P01_2 Solicittud de pago que no registra (aportante informa radicar solicitud)', 
        'P01_3 Aportante presenta problemas con portal', 
        'P01_4 Solicitud de pago radicada en OAA no hay PDA ni ON-BASE', 
        'P01_5 Solicito transcripción no se realizó solicitud de  pago'
      ]
      }
P02 = {
    'P02_Correccion_origen_y/o_datos_de_la_incapacidad': 
      [
        'P02_1 Solicita cambio de origen (nuevo dictamen)',
        'P02_2 Solicita modificar días de la incapacidad (error en transcripción) ajuste en pago',
        'P02_3 Solicita modificar datos de la incapacidad por error en la transcripción',
        'P02_4 Solicita modificar datos de la incapacidad no es procedente',
        'P02_5 Solicita ajustar la prórroga de incapacidades expedidas y ajustar conteo'
      ]
      }
P03 = {
    'P03 Solicitud de informacion tramites pago y transcripcion': 
      [
        'P03_1 Requiere información para tramitar licencia compartida y/o Flexible Ley 2114 de 2021', 
        'P03_2 Requiere información Decreto 1427 de 2022',
        'P03_3 Requiere información de creación de cuenta remite documentos',
        'P03_4 Requiere información del tramite para solicitar el pago de incapacidades',
        'P03_5 Requiere información cambio de cuenta bancaria por embargo',
        'P03_6 Requiere información del tramite para el pago de una incapacidad mayor a 540 días'
      ]
      }
P04 = {
    'P04 Solicitud de incapacidad y/o licencia con pago ya autorizado':
      [
        'P04_1 Solicitud pago de incapacidad autorizada con mas de 5 dias habiles',
        'P04_2 Solicitud pago de incapacidad autorizada con menos de 5 dias habiles',
        'P04_3 Solicitud pago de licencia autorizada con mas de 5 das habiles',
        'P04_4 Solicitud pago de licencia autorizada con menos de 5 días habiles'
      ]
      }
P05 = {
    'P05 Solicitud de incapacidad en proceso de autorizacion menor a 15 días': 
      [
        'P05_1 Aportante dependiente realiza solicitud de pago por proceso normal y radica PQRS', 
        'P05_2 Aportante independiente realiza solicitud de pago por proceso normal y radica PQRS'
      ]
      }

P06 = {
    'P06 Solicitud de pago a tercero autorizado por  fallecimiento del cotizante':
      [
        'P06_1 Solicitud de pago a tercero autorizado por  fallecimiento del cotizante'
      ]
      }
P07 = {
    'P07 Solicitud de retoma de Incapacidad y/o licencia por negacion anterior':
      [
        'P07_1 Documentos para Pago_cuenta ya creada no se ha retomado',
        'P07_10 Solicitud de certificado de EPS anterior remite certificado',
        'P07_11 Solicitud de certificado de Nueva EPS_aclara no tiene incapacidades en EPS anterior',
        'P07_12 Solicitud de pago de incapacidades con Concepto Favorable sin PCL',
        'P07_13 Mes causado',
        'P07_14 Error en la negación de Licencias por Pago Extemporáneo Decreto 1427 del 29 de Julio 2022',
        'P07_2 Documentos para Pago_incapacidad ya retomada en proceso masivo',
        'P07_3 Interrupción de Prórrogas',
        'P07_4 Periodos Mínimos de Cotización',
        'P07_5 Mora para el mes de evento',
        'P07_6 Reliquidaciones',
        'P07_7 Suspensión Laboral no remunerada',
        'P07_8 Relación laboral no vigente',
        'P07_9 Incapacidades menor a 180 días con concepto de rehabilitación desfavorable'      
      ]
      }
P08 = {
    'P08 Solicitud de Reliquidacion y/o ajuste en el valor liquidado':
      [
        'P08_1 No es procedente el valor que se requiere liquidar es de menor cuantia',
        'P08_2  No es procecedente el valor liquidado corresponde a IBC reportado sin novedad',
        'P08_3  Presenta novedad se remite para reliquidar valor'       
      ]
      }

P09 = {
    'P09 Mala atencion de OAA no radican solicitud de pago':
      [
        'P09_1 OAA No recibe solicitud',
        'P09_2 OAA No brinda información requerida'
      ]
      }

P10 = {
    'P10 Solicitud de pago de Incapacidad Inferior a 3 Días':
      [
        'P10_1 Incapacidad requerida con ajuste de prorroga procede para retomar', 
        'P10_2 No hay prorroga incapacidad inicial'
      ]
      }
P11 = {
    'P11 Solicitud de pago de incapacidades mayores a 180 días':
      [
        'P11_1 180 dias sin concepto de rehabilitación se debe retomar por incumplimiento normativo',
        'P11_2 CRH tardio solicita pago de incapacidades hasta la emisión del concepto',
        'P11_3 Solicita pago no tiene AFP',
        'P11_4 Solicita pago nuevo conteo (incapacidades no prorroga)-procede retoma',
        'P11_5 Solicita pago no está de acuerdo con la prorroga se ratifica respuesta'
      ]
      }
P12 = {
    'P12 Solicitud de pago de incapacidades mayores a 540 días':
      [
         'P12_1 Incapacidades mayores a 540 días sin PCLO con concepto de rehabilitación favorable',
         'P12_2  Incapacidades mayores a 540 días sin PCLO con concepto de rehabilitación desfavorable',
         'P12_3  Incapacidades mayores a 540 días con PCLO >50% en firme sin pensión',
         'P12_4 Incapacidades mayores a 540 días con PCLO <50% en firme sin reubicación',
         'P12_5 Incapacidades mayores a 540 días con PCLO <50% con apelación a juntas'
      ]
      }
P13 = {
    'P13 Solicitud de aclaracion de pago de incapacidades':
      [
         'P13_2 Solicitan aclarar el valor liquidado  incapacidad',
         'P13_3 Solicitan aclarar el valor liquidado  licencia de maternidad',
         'P13_4 Solicitan aclarar el valor liquidado  licencia de paternidad',
         'P13_1 Solicitan información de estados de las solicitudes de pago mayor a 3 años'
      ]
      }
P14 = {
    'P14 Solicitud de certificado detallado de incapacidades':
      [
        'P14_1 Certificado detallado de incapacidades para AFP con especificaciones',
        'P14_2 Certificado detallado de incapacidades para AFP requiere ajuste de prorroga',
        'P14_3 Devolucion de certificado de incapacidad por no cumplimiento de Decreto 1427',
        'P14_4 Solicitud de certificado de incapacidad requisitos Decreto 1427'
      ]
      }
P15 = {
    'P15 Usuario asignacion (Incapacidad Generada en EPS anterior)':
      [
        'P15_1 Incapacidad que por fecha incio corresponde a EPS anterior',
        'P15_2 Licencia de maternidad que por fecha incio corresponde a EPS anterior',
        'P15_3 Licencia de paternidad que por fecha incio corresponde a EPS anterior',
        'P15_4 Solicita pago de incapacidades al parecer prorroga no hay certificado de EPS anterior' 
      ]
      }
P16 = {
    'P16 Solicitud pago de incapacidad AT o EP':
      [
        'P16_1 Solicitud pago de incapacidad AT origen no calificado',
        'P16_2 Solicitud pago de incapacidad EP'
      ]
      }
P17 = {
    'P17 Incapacidad perdio vigencia para cobro':
      [
        'P17_1 Incapacidad perdio vigencia para cobro'
      ]
      }
P18 = {
    'P18 Solicitud de aclaracion de negacion de pago':
      [
        'P18_1 Incapacidades mayores a 180 no está de acuerdo con la prorroga',
        'P18_2 Incapacidades Menores a 180 días con concepto de rehabilitación desfavorable',
        'P18_3 Pago extemporáneo en Licencias Decreto 1427' 
      ]
      }
P19 = {
    'P19 Solicitud de pago de incapacidades reconocidas por tracto sucesivo-tutela':
      [
        'P19_1 Nueva incapacidad se liquida por tracto',
        'P19_2 Interrumpio prorroga',
        'P19_3 No se ha causado mes para pago',
        'P19_4 ya se dio cumplimiento nuevas incapacidades no están en el fallo',
        'P19_5 Afilido con PCL >50%',
        'P19_6 Incapacidad  no transcrita' 
      ]
      }
P20 = {
    'P20 solicitud de reconocimiento por cumpliento de fallos de tutela':
      [
       'P20_1 Fallo no cargado en v3',
       'P20_2 Ya se dio cumplimiento al fallo pago ya reclamado',
       'P20_3 Ya se dio cumplimiento al fallo pago pendiente por reclamar',
       'P20_4 La solicitud no corresponde a lo ordenado por el fallo incapacidades no cubiertas',
       'P20_5 Afiliado no tiene fallos de tutela' 
      ]
      }
P21 = {
    'P21 Solicitud de Aportante masivo':
      [
       'P21_1 Solicita detalle de incapacidades pagadas y negadas',
       'P21_2 Solicita retoma de pagos por causales de mes causado,ajuste de prorroga, EPS anterior',
       'P21_3 Solicita aclaraciones de liquidación'   
      ]
      }
P22 = {
    'P22 Información solicitud no es queja':
      [
        'P22_1 La EPS adjunta carta de manera informativa sin realizar solicitud de pago',
        'P22_2 Información relacionada con jurídica',
        'P22_3 Información relacionada con datos de aportante' 
      ]
      }

dataframes = [df]
for dicc in [P01, P02, P03, P04, P05, P06, P07, P08, P09, P10, P11, P12, P13, P14, P15, P16, P17, P18, P19, P20, P21, P22]:
    temp_df = pd.DataFrame(dicc)
    dataframes.append(temp_df)

df_final = pd.concat(dataframes, axis=1)

print(df_final.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\daale\OneDrive - NUEVA EPS\GO_PQR\datamaker\dataeraser.ipynb Cell 1 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/daale/OneDrive%20-%20NUEVA%20EPS/GO_PQR/datamaker/dataeraser.ipynb#W0sZmlsZQ%3D%3D?line=216'>217</a> P21 = {
#     <a href='vscode-notebook-cell:/c%3A/Users/daale/OneDrive%20-%20NUEVA%20EPS/GO_PQR/datamaker/dataeraser.ipynb#W0sZmlsZQ%3D%3D?line=217'>218</a>     'P21 Solicitud de Aportante masivo':
#     <a href='vscode-notebook-cell:/c%3A/Users/daale/OneDrive%20-%20NUEVA%20EPS/GO_PQR/datamaker/dataeraser.ipynb#W0sZmlsZQ%3D%3D?line=218'>219</a>       [
#    (...)
#     <a href='vscode-notebook-cell:/c%3A/Users/daale/OneDrive%20-%20NUEVA%20EPS/GO_PQR/datamaker/dataeraser.ipynb#W0sZmlsZQ%3D%3D?line=222'>223</a>       ]
# ...
